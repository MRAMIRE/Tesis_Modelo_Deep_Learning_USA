# %% [markdown]
# <a href="https://colab.research.google.com/github/MRAMIRE/Tesis_Modelo_Deep_Learning_USA/blob/master/4_4_Entrenamiento_RMS_Suma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROCESAMIENTO DE DATA:**
#
# ###FELIPE ANTONIO MELO CIFUENTES
#
# ###MARIA CAMILA RAMIREZ FERRO

# %% [markdown]
# ##### Clonación de repositorio github

# %%
import os
if os.path.exists('Tesis_Modelo_Deep_Learning_USA/'):
  # !git -C Tesis_Modelo_Deep_Learning_USA/ fetch --all
  # !git -C Tesis_Modelo_Deep_Learning_USA/ reset --hard origin/master
  # !git -C Tesis_Modelo_Deep_Learning_USA/ pull origin master;
else:
  # !git clone https://github.com/MRAMIRE/Tesis_Modelo_Deep_Learning_USA.git
# %cd Tesis_Modelo_Deep_Learning_USA/
from utils import *
from Unet import *
# Out:
# Cloning into 'Tesis_Modelo_Deep_Learning_USA'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 339 (delta 82), reused 90 (delta 38), pack-reused 189
# Receiving objects: 100% (339/339), 2.24 MiB | 26.98 MiB/s, done.
# Resolving deltas: 100% (168/168), done.
# /content/Tesis_Modelo_Deep_Learning_USA

# %% [markdown]
# ##### Permisos y cambio de directorio:

# %%
from google.colab import drive
#Permisos
drive.mount('/gdrive')
#Cambio de Directorio
# %cd /gdrive/My\ Drive/Tesis
#%cd /gdrive/Share\Whit\Me
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive/My Drive/Tesis
# '1. Exploración de los Datos'
# '2. Visualización de la Data.ipynb'
# '3. Pre-PorcesamientoV2-Data.Pre-PorcesamientoV2-Data'
# '5. Resultados_cross'
# '6. TensorBoard '
# '7. Submission'
#  check/
# 'Data Set.ipynb'
#  Entrenamiento-ADAM-Cross
#  Entrenamiento-ADAM-Suma
# 'Entrenamiento-RMS-Cross '
# 'Entrenamiento-RMS-Suma '
# 'Pruebas 9 12'/
#  Resultados
#  Resultados_suma
#  runs/
#  sample_submission.csv
#  set_test.csv
#  set_train.csv
#  test_images/
#  train.csv
#  train_images/

# %% [markdown]
# #####Importar librerias:

# %%
import numpy as np
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm_notebook as tqdm
import pylab as plt
from torch.autograd import Function
from torch import optim
from torch.utils.tensorboard import SummaryWriter
import logging
from torchvision import transforms
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %% [markdown]
# ```
# import matplotlib
# from torchvision import utils
# %matplotlib inline
# import argparse
# import sys
# ```

# %% [markdown]
# ##### Eval

# %%
def eval_net(net, loader, device, n_val):
    """Evaluation without the densecrf with the dice coefficient"""
    net.eval()
    tot = 0
    with tqdm(total=n_val, desc='Validation round', unit='img', leave=False) as pbarV:
        for batch in loader:
            imgs = batch['image']
            true_masks = batch['mask']

            imgs = imgs.to(device=device, dtype=torch.float32)
            true_masks = true_masks.to(device=device, dtype=torch.float32)

            mask_pred = net(imgs)

            for true_mask, pred in zip(true_masks, mask_pred ):
                tot +=  dice_coeff(mask_pred, true_masks)
            pbarV.update(imgs.shape[0])
    return tot.item() / n_val

# %% [markdown]
# ##### Suma

# %%
def suma(prediction,target):
  dice = dice_coeff(prediction,target)
  cross = cross_entropy(prediction,target)
  return cross + (1-dice)

# %% [markdown]
# ##### Def Train

# %%
def train_net(net,device,model_check,desc_check,epochs=5,batch_size=4,lr=0.1,save_cp=True,img_scale=0.5,n_workers=0):
  dir_checkpoint= model_check
  transform_img = transforms.Compose([transforms.Resize(350) , transforms.ToTensor()])
  train_dataset = CloudDataSet(csv_file ='set_train.csv', root_dir='./train_images/',transform = transform_img)
  n_train = len(train_dataset)
  val_dataset = CloudDataSet(csv_file ='set_test.csv', root_dir='./train_images/',transform = transform_img)
  n_val = len(val_dataset)
  n_data = n_val + n_train
  train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle=True, num_workers = n_workers)
  test_loader = DataLoader(val_dataset, batch_size =batch_size, shuffle=False, num_workers = n_workers)
  
  writer = SummaryWriter(comment=desc_check)
  global_step = 0
  logging.info(f'''Starting training:
        Epochs:          {epochs}
        Batch size:      {batch_size}
        Learning rate:   {lr}
        Training size:   {n_train}
        Validation size: {n_val}
        Checkpoints:     {save_cp}
        Device:          {device}
        Images scaling:  {img_scale}
    ''')
  net.to(device)
  optimizer = optim.RMSprop(net.parameters(), lr=lr, weight_decay=1e-8)
  criterion = suma
  scheduler = ReduceLROnPlateau(optimizer, patience=3)
  no_val = 0
  for epoch in range(epochs):
    net.train()
    with tqdm(total=n_train, desc=f'Epoch {epoch + 1}/{epochs}', unit='img') as pbar:
      for batch in train_loader:
        imgs = batch['image']
        imgs = imgs.to(device=device,dtype=torch.float32)

        true_masks = batch['mask']
        true_masks = true_masks.to(device=device,dtype=torch.float32)
        masks_pred = net(imgs)

        loss = criterion(masks_pred, true_masks)
        dice_loss = dice_coeff(masks_pred, true_masks)
        writer.add_scalar('Cross & Dice Loss/train', loss.item(), global_step)
        writer.add_scalar('Dice Loss/train',dice_loss.item(),global_step )

        pbar.set_postfix(**{'loss (batch)': loss.item()})

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        pbar.update(imgs.shape[0])
        global_step += 1
        
        if save_cp:
          try:
            os.mkdir(dir_checkpoint)
            logging.info('Created checkpoint directory')
          except OSError:
            pass
          torch.save(net.state_dict(),dir_checkpoint + f'CP_epoch{epoch + 1}.pth')
          logging.info(f'Checkpoint {epoch + 1} saved !')
    with torch.no_grad():
      val_score = eval_net(net, test_loader, device, n_val)
      logging.info('Validation cross entropy: {}'.format(val_score))
      writer.add_scalar('Dice Loss/test', val_score, global_step)
      no_val += 1
      print('Dice loss validacion #',no_val,': ',val_score)
      scheduler.step(val_score)
      writer.add_scalar('Learning Rate',optimizer.param_groups[0]['lr'],global_step )
      print(optimizer.param_groups[0]['lr'])

  writer.close()

# %% [markdown]
# ##### Train

# %%
net = UNet(3,4,1)
model_check= 'check/RMS-SUM/'
desc_check= 'Op-RMS_Cr-Sum_11-1'
train_net(net,'cuda',epochs=18,lr=0.1,model_check=model_check,desc_check=desc_check)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# HBox(children=(IntProgress(value=0, description='Epoch 1/18', max=4159, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 1 :  0.3032730421576469
# 0.1
# HBox(children=(IntProgress(value=0, description='Epoch 2/18', max=4159, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 2 :  0.3566425656275347
# 0.1
# HBox(children=(IntProgress(value=0, description='Epoch 3/18', max=4159, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 3 :  0.2815707976128785
# 0.1
# HBox(children=(IntProgress(value=0, description='Epoch 4/18', max=4159, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 4 :  0.32580788632305563
# 0.1
# HBox(children=(IntProgress(value=0, description='Epoch 5/18', max=4159, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 5 :  0.3931176722608372
# 0.1
# HBox(children=(IntProgress(value=0, description='Epoch 6/18', max=4159, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 6 :  0.31213689142624595
# 0.1
# HBox(children=(IntProgress(value=0, description='Epoch 7/18', max=4159, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 7 :  0.3450435536665803
# 0.010000000000000002
# HBox(children=(IntProgress(value=0, description='Epoch 8/18', max=4159, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 8 :  0.3882189298930921
# 0.010000000000000002
# HBox(children=(IntProgress(value=0, description='Epoch 9/18', max=4159, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 9 :  0.39060752995167175
# 0.010000000000000002
# HBox(children=(IntProgress(value=0, description='Epoch 10/18', max=4159, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 10 :  0.38999788247172407
# 0.010000000000000002
# HBox(children=(IntProgress(value=0, description='Epoch 11/18', max=4159, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 11 :  0.38528572198033073
# 0.0010000000000000002
# HBox(children=(IntProgress(value=0, description='Epoch 12/18', max=4159, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 12 :  0.399278878649964
# 0.0010000000000000002
# HBox(children=(IntProgress(value=0, description='Epoch 13/18', max=4159, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 13 :  0.39681749405754324
# 0.0010000000000000002
# HBox(children=(IntProgress(value=0, description='Epoch 14/18', max=4159, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 14 :  0.3990338139166141
# 0.0010000000000000002
# HBox(children=(IntProgress(value=0, description='Epoch 15/18', max=4159, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 15 :  0.4009839905709265
# 0.00010000000000000003
# HBox(children=(IntProgress(value=0, description='Epoch 16/18', max=4159, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 16 :  0.40272149028929344
# 0.00010000000000000003
# HBox(children=(IntProgress(value=0, description='Epoch 17/18', max=4159, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Validation round', max=1387, style=ProgressStyle(description_…
# Dice loss validacion # 17 :  0.3982602912226253
# 0.00010000000000000003
# HBox(children=(IntProgress(value=0, description='Epoch 18/18', max=4159, style=ProgressStyle(description_width…
# Buffered data was truncated after reaching the output size limit.
